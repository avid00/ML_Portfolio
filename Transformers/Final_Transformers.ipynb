# %% [markdown]
# # Transformer for Classifying Time-Series Lightcurves of Celestial Objects
# ### Student id: C00313459
# ### Name: Amisha Das
#
# ## 1. Introduction

# %% [markdown]
# This notebook focuses on using a Transformer-based deep leaning model for classifying lightcurve data. It does so by learning the pattern of an object's brightness vairation over time.
#
# It works with various strategies such as input normalisation, class weighting and feature engineering. At the end a confusion matrix is also used for analysing model accuracy.

# %% [markdown]
# [Data source](https://users.flatironinstitute.org/~polymathic/data/MultimodalUniverse/v1/plasticc/data/healpix=2260/)

# %% [markdown]
# Note:
#
# This notebook has been edited from the original notebook built by [Alice Martin and adapted to pytorch by Charles Ollion](https://colab.research.google.com/github/charlesollion/dlexperiments/blob/master/7-Transformers-Timeseries/Transformers_for_timeseries.ipynb)

# %% [markdown]
# ## 2. Defining Transformer model

# %%
import torch
import torch.nn as nn

class Transformer(nn.Module):
    def __init__(self, num_layers, D, H, hidden_mlp_dim, inp_features, out_features, dropout_rate):
        super().__init__()
        self.input_projection = nn.Linear(inp_features, D)
        self.transformer_layer = nn.TransformerEncoderLayer(d_model=D, nhead=H, dim_feedforward=hidden_mlp_dim, dropout=dropout_rate)
        self.encoder = nn.TransformerEncoder(self.transformer_layer, num_layers=num_layers)
        self.dropout = nn.Dropout(dropout_rate)
        self.output_layer = nn.Linear(D, out_features)

    def forward(self, x, mask):
        x = self.input_projection(x)
        x = self.encoder(x.transpose(0, 1), mask=mask)
        x = self.dropout(x)
        x = x.mean(dim=0)  
        return self.output_layer(x), {}

# %% [markdown]
# ### 2.2. Load preprocessed data
#
# This data ia already in 'combined_lightcurves_top5.npz'

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from torch.utils.data import TensorDataset, DataLoader

# %%
data = np.load("combined_lightcurves_top5.npz", allow_pickle=True)
X = data['X']  # (N, 6, 3, 150)
y = data['y']

# %%
# Reshape
X = X.transpose(0, 3, 1, 2).reshape(X.shape[0], X.shape[3], -1)  # (N, 150, 18)

# %% [markdown]
# Normalising features

# %%
N, T, F = X.shape
scaler = StandardScaler()
X = scaler.fit_transform(X.reshape(-1, F)).reshape(N, T, F)

encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
num_classes = len(np.unique(y_encoded))

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
import torch
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test_tensor, y_test_tensor), batch_size=32)

# %% [markdown]
# # 3. Training the model

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transformer = Transformer(
    num_layers=3,
    D=128,
    H=4,
    hidden_mlp_dim=256,
    inp_features=18,
    out_features=num_classes,
    dropout_rate=0.2
).to(device)

optimizer = torch.optim.Adam(transformer.parameters(), lr=1e-4)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.5, verbose=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# Due to high imbalance of classes and unavailable data, class weights were added to improve model accuracy.

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y_encoded), y=y_encoded)
class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

loss_fn = nn.CrossEntropyLoss(weight=class_weights)

num_epochs = 45
losses, val_losses = [], []

# %%
def create_mask(seq_len):
    return torch.zeros(seq_len, seq_len).type(torch.bool).to(device)

for epoch in range(num_epochs):
    transformer.train()
    epoch_loss = 0
    for x, y in train_loader:
        x, y = x.to(device), y.to(device)
        mask = create_mask(x.shape[1])
        logits, _ = transformer(x, mask)
        loss = loss_fn(logits, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    losses.append(epoch_loss / len(train_loader))

    # Validation
    transformer.eval()
    val_loss = 0
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            mask = create_mask(x.shape[1])
            logits, _ = transformer(x, mask)
            loss = loss_fn(logits, y)
            val_loss += loss.item()
        val_losses.append(val_loss / len(test_loader))
        scheduler.step(val_losses[-1])

    print(f"Epoch {epoch+1} | Train Loss: {losses[-1]:.4f} | Val Loss: {val_losses[-1]:.4f}")
# Out:
# Epoch 1 | Train Loss: 1.5993 | Val Loss: 1.5831
# Epoch 2 | Train Loss: 1.5391 | Val Loss: 1.5753
# Epoch 3 | Train Loss: 1.4810 | Val Loss: 1.3454
# Epoch 4 | Train Loss: 1.3753 | Val Loss: 1.3744
# Epoch 5 | Train Loss: 1.3209 | Val Loss: 1.1612
# Epoch 6 | Train Loss: 1.3033 | Val Loss: 1.1074
# Epoch 7 | Train Loss: 1.2297 | Val Loss: 1.0550
# Epoch 8 | Train Loss: 1.1694 | Val Loss: 1.1501
# Epoch 9 | Train Loss: 1.1464 | Val Loss: 1.1685
# Epoch 10 | Train Loss: 1.1353 | Val Loss: 1.0409
# Epoch 11 | Train Loss: 1.0776 | Val Loss: 0.9965
# Epoch 12 | Train Loss: 1.0647 | Val Loss: 0.9865
# Epoch 13 | Train Loss: 1.0246 | Val Loss: 0.8906
# Epoch 14 | Train Loss: 0.9827 | Val Loss: 0.9577
# Epoch 15 | Train Loss: 0.9588 | Val Loss: 0.9217
# Epoch 16 | Train Loss: 0.9422 | Val Loss: 0.9057
# Epoch 17 | Train Loss: 0.9231 | Val Loss: 0.7888
# Epoch 18 | Train Loss: 0.8945 | Val Loss: 0.9632
# Epoch 19 | Train Loss: 0.8927 | Val Loss: 0.8000
# Epoch 20 | Train Loss: 0.8651 | Val Loss: 0.7459
# Epoch 21 | Train Loss: 0.8317 | Val Loss: 0.7353
# Epoch 22 | Train Loss: 0.8065 | Val Loss: 0.7435
# Epoch 23 | Train Loss: 0.8097 | Val Loss: 0.7905
# Epoch 24 | Train Loss: 0.7743 | Val Loss: 0.7399
# Epoch 25 | Train Loss: 0.7640 | Val Loss: 0.7188
# Epoch 26 | Train Loss: 0.7653 | Val Loss: 0.7792
# Epoch 27 | Train Loss: 0.7427 | Val Loss: 0.7667
# Epoch 28 | Train Loss: 0.7525 | Val Loss: 0.7731
# Epoch 29 | Train Loss: 0.7314 | Val Loss: 0.7157
# Epoch 30 | Train Loss: 0.7112 | Val Loss: 0.7394
# Epoch 31 | Train Loss: 0.6792 | Val Loss: 0.7155
# Epoch 32 | Train Loss: 0.7322 | Val Loss: 0.8775
# Epoch 33 | Train Loss: 0.7041 | Val Loss: 0.7819
# Epoch 34 | Train Loss: 0.7400 | Val Loss: 0.8486
# Epoch 35 | Train Loss: 0.7190 | Val Loss: 0.7145
# Epoch 36 | Train Loss: 0.6736 | Val Loss: 0.6699
# Epoch 37 | Train Loss: 0.6553 | Val Loss: 0.7873
# Epoch 38 | Train Loss: 0.6670 | Val Loss: 0.7344
# Epoch 39 | Train Loss: 0.6507 | Val Loss: 0.7021
# Epoch 40 | Train Loss: 0.6508 | Val Loss: 0.6672
# Epoch 41 | Train Loss: 0.6377 | Val Loss: 0.8068
# Epoch 42 | Train Loss: 0.6290 | Val Loss: 0.6560
# Epoch 43 | Train Loss: 0.6238 | Val Loss: 0.6649
# Epoch 44 | Train Loss: 0.6731 | Val Loss: 0.6685
# Epoch 45 | Train Loss: 0.6495 | Val Loss: 0.6657

# %%
# 4. Evaluate
from sklearn.metrics import accuracy_score, classification_report
all_preds, all_targets = [], []
transformer.eval()
with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        mask = create_mask(x.shape[1])
        logits, _ = transformer(x, mask)
        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(y.cpu().numpy())

print("\n✅ Accuracy:", accuracy_score(all_targets, all_preds))
print("\n📊 Classification Report:\n", classification_report(all_targets, all_preds))

num_classes = len(np.unique(y_encoded))
# Out:
# ✅ Accuracy: 0.631578947368421
#
# 📊 Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.64      0.66       180
#            1       0.12      0.37      0.18        30
#            2       0.87      0.87      0.87        23
#            3       0.66      0.90      0.76        21
#            4       0.80      0.62      0.69       278
#
#     accuracy                           0.63       532
#    macro avg       0.62      0.68      0.63       532
# weighted avg       0.71      0.63      0.66       532

# %%
all_targets = []  # true labels
all_preds = []    #predicted labels

transformer.eval()
with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        mask = create_mask(x.shape[1])
        logits, _ = transformer(x, mask)
        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(y.cpu().numpy())

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Confusion Matrix

# %%
cm = confusion_matrix(all_targets, all_preds)
labels = encoder.classes_  # or use np.unique(all_targets) if encoder is not defined

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(all_targets), yticklabels=np.unique(all_targets))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
# Save these after model evaluation
all_targets = []  # True labels
all_preds = []    # Predicted labels

transformer.eval()
with torch.no_grad():
    for x, y in test_loader:
        x, y = x.to(device), y.to(device)
        mask = create_mask(x.shape[1])
        logits, _ = transformer(x, mask)
        preds = torch.argmax(logits, dim=1)
        all_preds.extend(preds.cpu().numpy())
        all_targets.extend(y.cpu().numpy())

# %%
from sklearn.metrics import precision_recall_fscore_support
import matplotlib.pyplot as plt
import numpy as np

# %%
# Per-class sample count
print("Sample count per class in test set:")
unique, counts = np.unique(y_test, return_counts=True)
for u, c in zip(unique, counts):
    print(f"Class {u}: {c}")

# Compute precision, recall, F1
precision, recall, f1, support = precision_recall_fscore_support(all_targets, all_preds, labels=np.unique(y_test))

# Bar chart
labels = [f"Class {i}" for i in np.unique(y_test)]
x = np.arange(len(labels))
width = 0.25

plt.figure(figsize=(10, 6))
plt.bar(x - width, precision, width, label='Precision')
plt.bar(x, recall, width, label='Recall')
plt.bar(x + width, f1, width, label='F1 Score')

plt.xticks(x, labels)
plt.ylabel("Score")
plt.title("Per-Class Precision, Recall, F1 Score")
plt.ylim(0, 1)
plt.legend()
plt.grid(True, axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
# Out:
# Sample count per class in test set:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Per-class sample count
#       2 print("Sample count per class in test set:")
# ----> 3 unique, counts = np.unique(y_test, return_counts=True)
#       4 for u, c in zip(unique, counts):
#       5     print(f"Class {u}: {c}")
#
# NameError: name 'y_test' is not defined

# %%
# Out:
#                                 Section  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                  Baseline Transformer
# 4        Transformer with Class Weights
# 5    Transformer with Weighted Sampling
# 6  Transformer with Feature Engineering
# 7                    Deeper Transformer
# 8      Final Transformer with Analytics
#
#                                                              Description  \
# 0                                                                    NaN
# 1                                                                    NaN
# 2  Initial Transformer with 18 input features and 5-class classification
# 3                              Added class weighting to handle imbalance
# 4                            Added WeightedRandomSampler to train_loader
# 5                   Merged original lightcurves with engineered features
# 6                                    Increased depth to improve accuracy
# 7   Added PR-F1 plots and confusion matrix to evaluate class performance
# 8                                                                    NaN
#
#    Level of Difficulty  Time Spent (mins)  \
# 0  making model deeper               20.0
# 1                  NaN               45.0
# 2               Medium               30.0
# 3                 High               25.0
# 4                 High               60.0
# 5                 High               20.0
# 6               Medium               25.0
# 7               Medium                NaN
# 8                  NaN                NaN
#
#                                          Change From  \
# 0                                                NaN
# 1  Basic architecture, no weighting or normalization
# 2                                       Uniform loss
# 3                     train_loader = DataLoader(...)
# 4                               X shape (N, 150, 18)
# 5                                       num_layers=2
# 6      accuracy_score and classification_report only
# 7                                                NaN
# 8                                                NaN
#
#                                                            Changed To  \
# 0                                                                 NaN
# 1                            Input normalization and CrossEntropyLoss
# 2                            Weighted loss based on class frequencies
# 3  train_loader = DataLoader(..., sampler=WeightedRandomSampler(...))
# 4                                                X shape (N, 150, 42)
# 5                                                        num_layers=4
# 6                      Added seaborn plots and sample count summaries
# 7                                                                 NaN
# 8                                                                 NaN
#
#                                                                                                                                                                                Old Code  \
# 0  transformer = Transformer(\n    num_layers=2,\n    D=64,\n    H=4,\n    hidden_mlp_dim=128,\n    inp_features=18,\n    out_features=num_classes,\n    dropout_rate=0.1\n).to(device)
# 1                                                                                                                                                       loss_fn = nn.CrossEntropyLoss()
# 2                                                                                                                                                       loss_fn = nn.CrossEntropyLoss()
# 3                                                                                                                                                                          shuffle=True
# 4                                                                                                                                                          X = ... .reshape(N, 150, 18)
# 5                                                                                                                                                                          num_layers=2
# 6                                                                                                                                                     print(classification_report(...))
# 7                                                                                                                                                                                   NaN
# 8                                                                                                                                                                                   NaN
#
#                                                                                                                                                                                 New Code
# 0  transformer = Transformer(\n    num_layers=3,\n    D=128,\n    H=4,\n    hidden_mlp_dim=256,\n    inp_features=18,\n    out_features=num_classes,\n    dropout_rate=0.2\n).to(device)
# 1                                                                                                 scaler = StandardScaler(); X = scaler.fit_transform(X.reshape(-1, F)).reshape(N, T, F)
# 2                                                                                                                                    loss_fn = nn.CrossEntropyLoss(weight=class_weights)
# 3                                                                                                                     sampler=WeightedRandomSampler(sample_weights, len(sample_weights))
# 4                                                                                                                                       X = np.concatenate([X, feats_expanded], axis=-1)
# 5                                                                                                                                                                           num_layers=4
# 6                                                                                                                                plot_confusion_matrix(...); plot_per_class_metrics(...)
# 7                                                                                                                                                                                    NaN
# 8                                                                                                                                                                                    NaN
